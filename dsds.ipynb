# %%
from final_transform import *
import pandas as pd
import os
import xml.etree.ElementTree as et

# %%
datapath='data/National_Men_2022-03-29_UEFA U21 Championship Qualification_Netherlands U21_vs_Switzerland U21_1904894_2022-03-29_Netherlands U21_vs_Switzerland U21_1904894_rawdata.xml'

# %%
final_transform(datapath, 'test')

# %%
df= pd.read_xml(datapath)
df[['action_name', 'second', 'player_name']].iloc[50:100]

# %%
path = 'data/'
action_list = []
for filename in os.listdir(path):
    if filename.endswith('.xml'):  # Check if the file is an XML file
        file_path = os.path.join(path, filename)
        print(file_path)
        new_path=file_path[:-4]+'_transformed'
        final_transform(file_path, new_path)
# Out:
# data/National_Men_2021-09-03_UEFA U21 Championship Qualification_Switzerland U21_vs_Gibraltar U21_1904973_2021-09-03_Switzerland U21_vs_Gibraltar U21_1904973_rawdata.xml
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass inaccurate
# Ball out of the field
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass inaccurate
# Pass interceptions
# Ball out of the field
# Attacking pass accurate
# Attacking pass inaccurate
# Attacking pass inaccurate
# Ball out of the field
# Attacking pass accurate
# Attacking pass inaccurate
# Cross interception
# Ball out of the field
# Attacking pass inaccurate
# Pass interceptions
# Attacking pass inaccurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass inaccurate
# Ball out of the field
# Attacking pass accurate
# Attacking pass inaccurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Unsuccessful dribbling
# Challenge
# Ball out of the field
# Attacking pass accurate
# Air challenge
# Attacking pass inaccurate
# Pass interceptions
# Successful dribbling
# Attacking pass accurate
# Challenge
# Attacking pass accurate
# Attacking pass inaccurate
# Pass interceptions
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Challenge
# Attacking pass inaccurate
# Attacking pass inaccurate
# Pass interceptions
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Goal
# Attacking pass accurate
# Attacking pass inaccurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Challenge
# Ball out of the field
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass inaccurate
# Pass interceptions
# Ball out of the field
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass inaccurate
# Attacking pass inaccurate
# Attacking pass accurate
# Attacking pass inaccurate
# Ball out of the field
# Attacking pass accurate
# Attacking pass inaccurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Blocked shot
# Shots blocked
# Ball out of the field
# Accurate key pass
# Air challenge
# Wide shot
# Ball out of the field
# Attacking pass inaccurate
# Attacking pass inaccurate
# Attacking pass accurate
# Attacking pass inaccurate
# Pass interceptions
# Challenge
# Ball out of the field
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Dribbling
# Attacking pass accurate
# Challenge
# Ball out of the field
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass inaccurate
# Pass interceptions
# Air challenge
# Attacking pass inaccurate
# Pass interceptions
# Attacking pass accurate
# Attacking pass inaccurate
# Pass interceptions
# Ball out of the field
# Attacking pass accurate
# Attacking pass inaccurate
# Pass interceptions
# Attacking pass inaccurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Ball out of the field
# Attacking pass inaccurate
# Ball out of the field
# Attacking pass accurate
# Attacking pass accurate
# Dribbling
# Attacking pass inaccurate
# Pass interceptions
# Ball out of the field
# Attacking pass accurate
# Air challenge
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Dribbling
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass inaccurate
# Attacking pass accurate
# Attacking pass inaccurate
# Attacking pass accurate
# Attacking pass inaccurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Unsuccessful dribbling
# Attacking pass accurate
# Successful dribbling
# Attacking pass inaccurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Accurate key pass
# Wide shot
# Ball out of the field
# Attacking pass accurate
# Air challenge
# Foul
# Attacking pass inaccurate
# Pass interceptions
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Accurate key pass
# Shot on target
# Attacking pass accurate
# Attacking pass accurate
# Challenge
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass inaccurate
# Attacking pass inaccurate
# Pass interceptions
# Attacking pass accurate
# Attacking pass inaccurate
# Pass interceptions
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Dribbling
# Attacking pass accurate
# Attacking pass inaccurate
# Pass interceptions
# Ball out of the field
# Attacking pass accurate
# Wide shot
# Ball out of the field
# Attacking pass accurate
# Air challenge
# Attacking pass inaccurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass accurate
# Attacking pass inaccurate
# Attacking pass inaccurate
# Attacking pass accurate
# Inaccurate key pass
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 8
#       6 print(file_path)
#       7 new_path=file_path[:-4]+'_transformed'
# ----> 8 final_transform(file_path, new_path)
#
# File c:\Users\Rui\BA\Instat_toWyscout_transform\final_transform.py:8, in final_transform(path, filename)
#       6 def final_transform(path, filename):
#       7     warnings.filterwarnings('ignore')
# ----> 8     dataframe= pandas_transform(path)
#       9     pandas_to_json(dataframe, filename)
#
# File c:\Users\Rui\BA\Instat_toWyscout_transform\instat_to_wyscout_pandas.py:332, in pandas_transform(path)
#     330 index = 0
#     331 while (True):
# --> 332     index, wyscoutdf = create_event(instatdf, index, wyscoutdf)
#     333     if(instatdf['action_name'].iloc[index]=='Match end'):
#     334         break
#
# File c:\Users\Rui\BA\Instat_toWyscout_transform\instat_to_wyscout_pandas.py:276, in create_event(instat, ind, wyscout)
#     261         wyscout = pd.concat([wyscout, pd.DataFrame([throwinevent])], ignore_index=True)
#     263     '''
#     264     #add touch attribute if needed
#     265     if(wyscout['pass.recipient.name'].iloc[-1]==playername and typeprimary!='touch'):
#    (...)
#     274             wyscout = pd.concat([wyscout, pd.DataFrame([touchevent])], ignore_index=True)
#     275     '''
# --> 276 wyscout = pd.concat([wyscout, pd.DataFrame([new_event])], ignore_index=True)
#     278 #check when second event has to be generated
#     279 if (typeprimary=='duel'):
#
# File c:\Users\Rui\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:817, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     808         columns = ensure_index(columns)
#     809     arrays, columns, index = nested_data_to_arrays(
#     810         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     811         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     815         dtype,
#     816     )
# --> 817     mgr = arrays_to_mgr(
#     818         arrays,
#     819         columns,
#     820         index,
#     821         dtype=dtype,
#     822         typ=manager,
#     823     )
#     824 else:
#     825     mgr = ndarray_to_mgr(
#     826         data,
#     827         index,
#    (...)
#     831         typ=manager,
#     832     )
#
# File c:\Users\Rui\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:152, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     149 axes = [columns, index]
#     151 if typ == "block":
# --> 152     return create_block_manager_from_column_arrays(
#     153         arrays, axes, consolidate=consolidate, refs=refs
#     154     )
#     155 elif typ == "array":
#     156     return ArrayManager(arrays, [index, columns])
#
# File c:\Users\Rui\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:2091, in create_block_manager_from_column_arrays(arrays, axes, consolidate, refs)
#    2089     raise_construction_error(len(arrays), arrays[0].shape, axes, e)
#    2090 if consolidate:
# -> 2091     mgr._consolidate_inplace()
#    2092 return mgr
#
# File c:\Users\Rui\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1750, in BlockManager._consolidate_inplace(self)
#    1744 def _consolidate_inplace(self) -> None:
#    1745     # In general, _consolidate_inplace should only be called via
#    1746     #  DataFrame._consolidate_inplace, otherwise we will fail to invalidate
#    1747     #  the DataFrame's _item_cache. The exception is for newly-created
#    1748     #  BlockManager objects not yet attached to a DataFrame.
#    1749     if not self.is_consolidated():
# -> 1750         self.blocks = _consolidate(self.blocks)
#    1751         self._is_consolidated = True
#    1752         self._known_consolidated = True
#
# File c:\Users\Rui\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:2217, in _consolidate(blocks)
#    2215 new_blocks: list[Block] = []
#    2216 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2217     merged_blocks, _ = _merge_blocks(
#    2218         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2219     )
#    2220     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2221 return tuple(new_blocks)
#
# File c:\Users\Rui\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:2252, in _merge_blocks(blocks, dtype, can_consolidate)
#    2249     new_values = new_values[argsort]
#    2250     new_mgr_locs = new_mgr_locs[argsort]
# -> 2252     bp = BlockPlacement(new_mgr_locs)
#    2253     return [new_block_2d(new_values, placement=bp)], True
#    2255 # can't consolidate --> no merge
#
# KeyboardInterrupt:
