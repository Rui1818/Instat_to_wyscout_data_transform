# %%
from instat_to_wyscout_pandas import *

# %%
df=pandas_transform("data/InStat_AXA_Super_2023-06-02_Switzerland. AXA Women's Super League_Servette Chenois_vs_Zurich_2582307_2023-06-02_Servette Chenois_vs_Zurich_2582307_rawdata - Kopie.xml")
# Out:
# c:\Users\Rui\BA\Instat_toWyscout_transform\instat_to_wyscout_pandas.py:259: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   wyscoutdf = pd.concat([wyscoutdf, pd.DataFrame([event])], ignore_index=True)

# %%
df[['type.primary','type.secondary', 'matchTimestamp', 'player.name', 'groundDuel.duelType', 'aerialDuel.opponent.name', 'matchPeriod']].iloc[0:780]
# Out:
#           type.primary                                     type.secondary  \
# 0                 pass                  [back_pass, short_or_medium_pass]
# 1                 pass  [forward_pass, pass_to_final_third, loss, long...
# 2    game_interruption                                         [ball_out]
# 3                 pass         [forward_pass, loss, short_or_medium_pass]
# 4    game_interruption                                         [ball_out]
# ..                 ...                                                ...
# 775            offside                               [loss, touch_in_box]
# 776          free_kick                                                 []
# 777               duel             [dribble, defensive_duel, aerial_duel]
# 778               duel                      [offensive_duel, aerial_duel]
# 779               pass                       [loss, short_or_medium_pass]
#
#     matchTimestamp             player.name groundDuel.duelType  \
# ...
